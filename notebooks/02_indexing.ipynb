# %% [markdown]
# ### Note:
# I use Colab to utilize T4 GPU to embedding faster.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !git clone https://github.com/BTL4w/medagent-rag-end2end.git
# Out:
# Cloning into 'medagent-rag-end2end'...
# remote: Enumerating objects: 107, done.
# remote: Counting objects: 100% (107/107), done.
# remote: Compressing objects: 100% (84/84), done.
# remote: Total 107 (delta 27), reused 94 (delta 14), pack-reused 0 (from 0)
# Receiving objects: 100% (107/107), 26.91 KiB | 984.00 KiB/s, done.
# Resolving deltas: 100% (27/27), done.

# %%
# !pip install -q -r "/content/medagent-rag-end2end/requirements.txt"
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 49.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.9/64.9 kB 8.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 742.8/742.8 kB 59.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 73.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 280.7/280.7 kB 30.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 97.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.0/51.0 kB 5.8 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires requests==2.32.4, but you have requests 2.33.1 which is incompatible.

# %%
import os
os.environ["PINECONE_API_KEY"] = "YOUR_API_HERE"
os.environ["HF_TOKEN"] = "YOUR_API_HERE"

# %%
# %cd /content/medagent-rag-end2end
# Out:
# /content/medagent-rag-end2end

# %%
# Change the input path and namespace every time you want to index
# !python -m src.ingestion.indexing \
  --input "/content/drive/MyDrive/youmed_dataset/processed/youmed_articles_medicine_processed.jsonl" \
  --index-name "medrag-agent-end2end" \
  --namespace "medicine" \ 
  --model-name "BAAI/bge-m3" \
  --chunk-size 600 \
  --chunk-overlap 50 \
  --batch-size 64 \
  --metric cosine \
  --cloud aws \
  --region us-east-1
# Out:
# [1/4] Chunking documents...
# Generated 8525 chunks.
# [2/4] Creating embeddings...
# Loading weights: 100% 391/391 [00:00<00:00, 933.64it/s, Materializing param=pooler.dense.weight]
# Embeddings shape: (8525, 1024)
# [3/4] Connecting Pinecone...
# [4/4] Upserting vectors...
# Upsert batches: 100% 134/134 [01:15<00:00,  1.78it/s]
# Indexing completed successfully.
# Index: medrag-agent-end2end
# Namespace: medicine
# Total vectors: 8525
