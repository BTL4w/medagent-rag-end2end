# %%
import os
import sys

sys.path.append(os.path.abspath(".."))  # từ notebooks/ lên root

from src.agents.router import route_query

# %%
route_query("Người bị hen phế quản có thể dùng Propranolol không và nguy cơ gì?")
# Out:
# {'route': 'complex_qa'}
