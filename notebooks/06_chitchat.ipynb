# %% [markdown]
# # Chitchat route

# %%
import sys
import os

sys.path.append(os.path.abspath(".."))  # từ notebooks/ lên root

from src.agents.orchestrator import run_agent
from src.agents.router import route_query
from src.agents.synthesizer import synthesize_answer

# %%
query1 = "Hi, bạn là ai?"

# %%
route_query(query1)
# Out:
# {'route': 'chitchat'}

# %%
synthesize_answer(query1, [])
# Out:
# 'Chào bạn, mình là trợ lý y khoa ảo, hỗ trợ cung cấp thông tin về bệnh lý, thuốc và sức khỏe. Bạn muốn hỏi về bệnh lý, thuốc hay vấn đề sức khỏe nào?'

# %%
query2 = 'bạn làm được những gì?'

# %%
run_agent(query2)
# Out:
# {'query': 'bạn làm được những gì?',
#  'route': 'unsupported',
#  'route_reason': '',
#  'sub_queries': [],
#  'answer': 'Truy vấn nằm ngoài phạm vi hỗ trợ hiện tại. Nếu bạn có câu hỏi y khoa cụ thể, hãy gửi lại rõ hơn.',
#  'citations': [],
#  'contexts': [],
#  'error': None}
